# %% [markdown]
# <a href="https://colab.research.google.com/github/gerhardteduardo/physics-computational/blob/main/trigonometric.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sine(x):
  return np.sin(x)

# %%
def cosine(x):
  return np.cos(x)

# %%
def tan(x):
  return np.tan(x)

# %%
N = 1000
x = np.linspace(-5 * np.pi, 5 * np.pi, N)
y_sin = sine(x)
y_cos = cosine(x)
y_tg = tan(x)
y_tg[(y_tg > 10) | (y_tg < -10)] = np.nan

# %%
plt.figure(figsize=(16, 6))
plt.plot(x, y_sin, label='sin(x)')
plt.plot(x, y_cos, label='cos(x)')
plt.plot(x, y_tg, label='tan(x)')
plt.title('Trigonometric Functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True, linestyle='--', alpha=1)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.show()
