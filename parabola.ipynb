# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def F(x):
  return x**2

# %%
N = 100
x = np.linspace(-60, 60, N)
y = F(x)

# %%
plt.plot(x, y)
plt.xlabel('X')
plt.ylabel('X²')
plt.title('F(x)')
plt.grid()
plt.show()
