# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def F(x):
  return x**2

# %%
N = 10
x = np.linspace(0, 100, N)
y = F(x)

# %%
plt.plot(x, y)
plt.xlabel('X')
plt.ylabel('X²')
plt.title('F(x)')
plt.show()
